# %%
import os
import pickle
import numpy as np

# %%
N1 = 1000000
kappa_range = (np.linspace(-1, 1, 20))**3
max_new = 0.115+0.003
min_new = 0.115-0.003
kappa_range = (kappa_range-kappa_range.min()) * (max_new - min_new) / 2 + min_new

num_ensambles = 3000
M1 = np.empty((len(kappa_range), num_ensambles))
for n in range(num_ensambles):
    with open('results/{0}_{1}_rho_critical.p'.format(n, N), "rb") as f:
        mags = pickle.load(f)
        for k in range(len(kappa_range)):
            m = mags[k]
            M1[k,n] = m

# %%
N2 = 50000
kappa_range = (np.linspace(-1, 1, 20))**3
max_new = 0.115+0.003
min_new = 0.115-0.003
kappa_range = (kappa_range-kappa_range.min()) * (max_new - min_new) / 2 + min_new

num_ensambles = 20000
M2 = np.empty((len(kappa_range), num_ensambles))
for n in range(num_ensambles):
    with open('results/{0}_{1}_rho_critical.p'.format(n, N), "rb") as f:
        mags = pickle.load(f)
        for k in range(len(kappa_range)):
            m = mags[k]
            M2[k,n] = m

# %%
N3 = 100000
kappa_range = (np.linspace(-1, 1, 20))**3
max_new = 0.115+0.003
min_new = 0.115-0.003
kappa_range = (kappa_range-kappa_range.min()) * (max_new - min_new) / 2 + min_new

num_ensambles = 20000
M3 = np.empty((len(kappa_range), num_ensambles))
for n in range(num_ensambles):
    with open('results/{0}_{1}_fig10_rho_critical.p'.format(n, N), "rb") as f:
        mags = pickle.load(f)
        for k in range(len(kappa_range)):
            m = mags[k]
            M3[k,n] = m
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-98303972c8f3> in <module>
#       8 M3 = np.empty((len(kappa_range), num_ensambles))
#       9 for n in range(num_ensambles):
# ---> 10     with open('results/{0}_{1}_fig10_rho_critical.p'.format(n, N), "rb") as f:
#      11         mags = pickle.load(f)
#      12         for k in range(len(kappa_range)):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/0_50000_fig10_rho_critical.p'

# %%
N3 = 100000
kappa_range = (np.linspace(-1, 1, 20))**3
max_new = 0.115+0.003
min_new = 0.115-0.003
kappa_range = (kappa_range-kappa_range.min()) * (max_new - min_new) / 2 + min_new

num_ensambles = 20000
M3 = np.empty((len(kappa_range), num_ensambles))
for n in range(num_ensambles):
    with open('results/{0}_{1}_fig10_rho_critical.p'.format(n, N), "rb") as f:
        mags = pickle.load(f)
        for k in range(len(kappa_range)):
            m = mags[k]
            M3[k,n] = m

# %%
N3 = 100000
kappa_range = (np.linspace(-1, 1, 20))**3
max_new = 0.115+0.003
min_new = 0.115-0.003
kappa_range = (kappa_range-kappa_range.min()) * (max_new - min_new) / 2 + min_new

num_ensambles = 20000
M3 = np.empty((len(kappa_range), num_ensambles))
for n in range(num_ensambles):
    with open('results/{0}_{1}_fig10_rho_critical.p'.format(n, N), "rb") as f:
        mags = pickle.load(f)
        for k in range(len(kappa_range)):
            m = mags[k]
            M3[k,n] = m

# %%
N3 = 100000
kappa_range = (np.linspace(-1, 1, 20))**3
max_new = 0.115+0.003
min_new = 0.115-0.003
kappa_range = (kappa_range-kappa_range.min()) * (max_new - min_new) / 2 + min_new

num_ensambles = 20000
M3 = np.empty((len(kappa_range), num_ensambles))
for n in range(num_ensambles):
    with open('results/{0}_{1}_fig10_rho_critical.p'.format(n, N), "rb") as f:
        mags = pickle.load(f)
        for k in range(len(kappa_range)):
            m = mags[k]
            M3[k,n] = m

# %%
,  145923,  212936, 310723

# %%
m0_1M = np.mean(M1[10][M1[10]<0.15])
m0_50k = np.mean(M2[10][M2[10]<0.15])

# %%
z = np.polyfit(np.log([50000, 1000000]), np.log([m0_50k, m0_1M]), 1)
print(z)
p = np.poly1d(z)
# Out:
# [ 0.09353027 -3.39640378]

# %%
m0_1M
# Out:
# 0.1219388743718593

# %%
m0_50k
# Out:
# 0.09214175898148826
