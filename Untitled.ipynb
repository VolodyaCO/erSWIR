# %%
from mpmath import findroot
import numpy as np
from scipy.optimize import fsolve, newton, root
from sympy.solvers import solve

# %%
def mp(kappa, rho):
    a = kappa*8 - 1/(1-rho)
    b = 0.5*kappa*64*(0.5-2*kappa)
    c = (1/6)*kappa*(4*kappa*kappa - kappa - 0.25)*8*8*8
    return -b/(3*c) + np.sqrt(b*b/(9*c*c)-a/(3*c))

def mm(kappa, rho):
    a = kappa*8 - 1/(1-rho)
    b = 0.5*kappa*64*(0.5-2*kappa)
    c = (1/6)*kappa*(4*kappa*kappa - kappa - 0.25)*8*8*8
    return -b/(3*c) - np.sqrt(b*b/(9*c*c)-a/(3*c))

# %%
def F(m, kappa, rho):
    a = kappa*8 - 1/(1-rho)
    b = 0.5*kappa*64*(0.5-2*kappa)
    c = (1/6)*kappa*(4*kappa*kappa - kappa - 0.25)*8*8*8
    return rho/(1-rho) + a*m + b*m*m + c*m*m*m

# %%
def find_rho(rho):
    fp = lambda kappa: F(mp(kappa, rho), kappa, rho)
    fm = lambda kappa: F(mm(kappa, rho), kappa, rho)
    kappap = findroot(fp, 0.108+1j*0)
    kappam = findroot(fm, 0.108+1j*0)
    return kappap[0] - kappam[0]

# %%
solve(find_rho, 0.00747)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     367         a = a.replace('\n', '')
# --> 368         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     369     except (TokenError, SyntaxError) as exc:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/parsing/sympy_parser.py in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#     964
# --> 965     return eval_expr(code, local_dict, global_dict)
#     966
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/parsing/sympy_parser.py in eval_expr(code, local_dict, global_dict)
#     877     expr = eval(
# --> 878         code, global_dict, local_dict)  # take local objects in preference
#     879
#
# SyntaxError: invalid syntax (<string>, line 1)
#
# During handling of the above exception, another exception occurred:
#
# SympifyError                              Traceback (most recent call last)
# <ipython-input-55-3f24ac561140> in <module>
# ----> 1 solve(find_rho, 0.00747)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#     916                        )
#     917                       )
# --> 918     f, symbols = (_sympified_list(w) for w in [f, symbols])
#     919
#     920     implicit = flags.get('implicit', False)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in <genexpr>(.0)
#     916                        )
#     917                       )
# --> 918     f, symbols = (_sympified_list(w) for w in [f, symbols])
#     919
#     920     implicit = flags.get('implicit', False)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in _sympified_list(w)
#     907
#     908     def _sympified_list(w):
# --> 909         return list(map(sympify, w if iterable(w) else [w]))
#     910     bare_f = not iterable(f)
#     911     ordered_symbols = (symbols and
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     368         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     369     except (TokenError, SyntaxError) as exc:
# --> 370         raise SympifyError('could not parse %r' % a, exc)
#     371
#     372     return expr
#
# SympifyError: Sympify of expression 'could not parse '<function find_rho at 0x7f378cdfc378>'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)

# %%
find_rho(2e-3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-11f2708f8636> in <module>
# ----> 1 find_rho(2e-3)
#
# <ipython-input-66-26d54a342d1d> in find_rho(rho)
#       2     fp = lambda kappa: F(mp(kappa, rho), kappa, rho)
#       3     fm = lambda kappa: F(mm(kappa, rho), kappa, rho)
# ----> 4     kappap = findroot(fp, 0.108+1j*0)
#       5     kappam = findroot(fm, 0.108+1j*0)
#       6     return kappap[0] - kappam[0]
#
# ~/anaconda3/lib/python3.7/site-packages/mpmath/calculus/optimization.py in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     926         # detect multidimensional functions
#     927         try:
# --> 928             fx = f(*x0)
#     929             multidimensional = isinstance(fx, (list, tuple, ctx.matrix))
#     930         except TypeError:
#
# <ipython-input-66-26d54a342d1d> in <lambda>(kappa)
#       1 def find_rho(rho):
# ----> 2     fp = lambda kappa: F(mp(kappa, rho), kappa, rho)
#       3     fm = lambda kappa: F(mm(kappa, rho), kappa, rho)
#       4     kappap = findroot(fp, 0.108+1j*0)
#       5     kappam = findroot(fm, 0.108+1j*0)
#
# <ipython-input-60-3f99b130d662> in mp(kappa, rho)
#       3     b = 0.5*kappa*64*(0.5-2*kappa)
#       4     c = (1/6)*kappa*(4*kappa*kappa - kappa - 0.25)*8*8*8
# ----> 5     return -b/(3*c) + np.sqrt(b*b/(9*c*c)-a/(3*c))
#       6
#       7 def mm(kappa, rho):
#
# AttributeError: 'mpc' object has no attribute 'sqrt'
